# %% [markdown]
# # FEMA Disaster Declaration Analysis
#
# This project analyzes FEMA disaster declaration data using Python, pandas, SQLite, and SQL. The goal is to identify disaster trends by state, incident type, and year.

# %% [markdown]
# ## imports

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Database Connection

# %%
BASE_DIR = Path.cwd().parent
db_path = BASE_DIR / "database" / "disasters.db"

conn = sqlite3.connect(db_path)

# %% [markdown]
# ## Dataset
#
# The dataset comes from FEMA Disaster Declarations Summaries. It contains nearly 70,000 disaster declaration records with information such as state, incident type, declaration date, fiscal year, and declaration title.
